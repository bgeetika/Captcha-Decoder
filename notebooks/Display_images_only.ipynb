# %%
# %matplotlib inline
import matplotlib as mpl
mpl.use('Agg')
from matplotlib.pyplot import imshow

# %%
import os
from PIL import Image
import numpy
import random
image_dir = '/home/geetika/captcha/dataset_ssd_1T/variable_dataset'
files = os.listdir(image_dir)

# %%
from IPython.display import Image as im
#file_path = os.path.join(image_dir, random.choice(files))
#file_path = os.path.join('/home/sujeetb/cvision/ps1/dogs_skimage_hogh_line_acc.jpg')
#file_path = os.path.join('/home/geetika/captcha/dataset_ssd_1T/complexdataset_nvocab/acuracy_number_of_images.jpeg')
#file_path = os.path.join('/home/geetika/captcha/dataset_ssd_1T/website_data_nvocab/number_of_images__training_loss_lstm_website.jpeg')
#file_path = os.path.join(image_dir, random.choice(files))
file_path = os.path.join('/home/geetika/captcha/dataset_ssd_1T/website_data_nvocab/number_of_images__training_time_lstm_website.jpeg')
im(file_path)

#imshow(numpy.asarray(Image.open(file_path).convert('L')))
#print numpy.asarray(Image.open(file_path).convert('L')).shape
