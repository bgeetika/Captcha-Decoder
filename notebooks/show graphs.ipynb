# %%
# %matplotlib inline

import matplotlib as mpl
mpl.use('Agg')
from matplotlib.pyplot import imshow
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:923: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   if warn: warnings.warn(_use_error_msg)

# %%
import glob
from PIL import Image
import numpy
import random
import os

#PYTHON_CREATE_FILE = "/home/geetika/Captcha-Decoder/model/create_graph.py"
import model.create_graph as cg

# %%
direc  = "/home/geetika/captcha/dataset_ssd_1T/simpledataset_nvocab/"
prefix = "lstm_variable"
os.chdir(direc)
files = glob.glob("*.csv")

# %%
from IPython.display import Image as im
for filen in files:
    if prefix in filen:
        out_file = cg.main_func(filen)
        filepath = direc + out_file
        print filepath
        im(filepath)
# Out:
# /home/geetika/captcha/dataset_ssd_1T/simpledataset_nvocab/acuracy__testing_acc_lstm_variable_run.jpeg
# /home/geetika/captcha/dataset_ssd_1T/simpledataset_nvocab/acuracy__training_acc_lstm_variable_run.jpeg
# /home/geetika/captcha/dataset_ssd_1T/simpledataset_nvocab/number_of_images__training_time_lstm_variable_run.jpeg
# /home/geetika/captcha/dataset_ssd_1T/simpledataset_nvocab/number_of_images__training_loss_lstm_variable_run.jpeg
